# %% [markdown]
# Se importa aparte << mat73 >>, de lo contrario falla

# %%
import mat73

# %% [markdown]
# Se importan el resto de las librerías

# %%
import numpy as np
import json
import pandas as pd
import random

# %% [markdown]
# Se llama al archivo con los datos

# %%
mat = mat73.loadmat('DATOSTJII_New7.mat')

# %% [markdown]
# Inputs

# %%
w_length = 24

# %% [markdown]
# Columnas en los datos

# %%
for key, value in mat.items():
    print(key)
# Out:
# array_shots
# data
# originalData
# signals

# %% [markdown]
# Señales, siendo las principales 'BOL5' y 'Densidad2_'

# %%
print(mat['signals'])
# Out:
# ['ACTON275', 'BOL5', 'Densidad2_', 'ECE7', 'GR', 'GR2', 'HALFAC3', 'IACCEL1', 'RX306']

# %%
print('Número de experimentos:',len(mat['array_shots']))
# Out:
# Número de experimentos: 430

# %% [markdown]
# Sección para encontrar los tiempos mínimos y máximos para trabajar en los intervalos justos.

# %%
times_per_experiments = {}
descargas_out = []

# %%
for descarga in np.arange(len(mat['array_shots'])):
    min_times = []
    max_times = []
    try:
        for signal in np.arange(1,10):
            times = mat['originalData'][descarga][signal][:,0]
            values = mat['originalData'][descarga][signal][:,1]
            min_times.append(np.trunc(100 * np.min(times)) / 100)
            max_times.append(np.trunc(100 * np.max(times)) / 100)
        min_time = np.max(np.array(min_times))
        max_time = np.min(np.array(max_times))
        times_per_experiments[str(mat['originalData'][descarga][0])]=[min_time,max_time]
    except:
        descargas_out.append(str(mat['originalData'][descarga][0]))

# %% [markdown]
# Descargas con señales en nulos:

# %%
print('N° de descargas con alguna señal completa en nulo:',len(descargas_out))
print('N° de descargas:',len(times_per_experiments))
# Out:
# N° de descargas con alguna señal completa en nulo: 44
# N° de descargas: 386

# %%
with open("times.json", "w") as outfile:
    json.dump(times_per_experiments, outfile)

# %%
keys = list(times_per_experiments.keys())
random.shuffle(keys)

shuffled_times = dict()
for key in keys:
    shuffled_times.update({key: times_per_experiments[key]})

# %%
ventana = []
mins = []
for descarga in shuffled_times:
    windows = []
    for c,data in enumerate(mat['originalData'][mat['originalData']==float(descarga)]):
        if c!=0:
            data[:,0] = np.trunc(100 * data[:,0]) / 100
            df = pd.DataFrame(data, columns = ['time',mat['signals'][c-1]])
            df = df.loc[(df['time']>=float(shuffled_times[str(descarga)][0])) & (df['time']<=float(shuffled_times[str(descarga)][1]))]
            while True:
                if len(df)%float(w_length) == 0: 
                    break
                else: 
                    df = df.iloc[:len(df)-1]
                    
            windows.append(len(df))
    ventana.append(np.min(windows))
    mins.append(np.argmin(windows))
    
for d,(descarga,m) in enumerate(zip(shuffled_times,mins)):
    ref_time = mat['originalData'][mat['originalData']==float(descarga)][m][:,0]
    ref_time = np.trunc(100 * ref_time) / 100
    if d<int(len(shuffled_times)*0.8):
        for c,data in enumerate(mat['originalData'][mat['originalData']==float(descarga)]):
            if c!=0:
                activate = True
                data[:,0] = np.trunc(100 * data[:,0]) / 100
                df = pd.DataFrame(data, columns = ['time',mat['signals'][c-1]])
                df = df.loc[(df['time']>=float(shuffled_times[str(descarga)][0])) & (df['time']<=float(shuffled_times[str(descarga)][1]))]
                for tm in ref_time:
                    try:
                        df_f = df.loc[(df['time']==float(tm))].iloc[:1]
                        if len(df_f)!=0 and activate:
                            activate = False
                            df_2f = df_f
                        elif len(df_f)!=0:
                            df_2f = pd.concat([df_2f, df_f], axis=0)
                    except:
                        pass
                df_2f.columns = ['time', mat['signals'][c-1]]
                if c == 1:
                    #df2 = df.sample(n = int(ventana[d]))
                    df2 = df_2f.sort_index()
                    df2 = df2.reset_index(drop=True)
                else:
                    
                    #df1 = df.sample(n = int(ventana[d]))
                    df1 = df_2f.sort_index()
                    df1 = df1.reset_index(drop=True)
                    #print(df1)
                    df1 = df1[mat['signals'][c-1]]
                    df2 = pd.concat([df2, df1], axis=1)
        if d == 0:
            df_train = df2
        else:
            df_train = pd.concat([df_train,df2],axis=0)
    else:
        for c,data in enumerate(mat['originalData'][mat['originalData']==float(descarga)]):
            if c!=0:
                activate = True
                data[:,0] = np.trunc(100 * data[:,0]) / 100
                df = pd.DataFrame(data, columns = ['time',mat['signals'][c-1]])
                df = df.loc[(df['time']>=float(shuffled_times[str(descarga)][0])) & (df['time']<=float(shuffled_times[str(descarga)][1]))]
                for tm in ref_time:
                    try:
                        df_f = df.loc[df['time']==float(tm)].iloc[:1]
                        if len(df_f)!=0 and activate:
                            activate = False
                            df_2f = df_f
                        elif len(df_f)!=0:
                            df_2f = pd.concat([df_2f, df_f], axis=0)
                    except:
                        pass
                df_2f.columns = ['time', mat['signals'][c-1]]
                if c == 1:
                    #df2 = df.sample(n = int(ventana[d]))
                    df2 = df_2f.sort_index()
                    df2 = df2.reset_index(drop=True)
                else:
                    #df1 = df.sample(n = int(ventana[d]))
                    df1 = df_2f.sort_index()
                    df1 = df1.reset_index(drop=True)
                    df1 = df1[mat['signals'][c-1]]
                    df2 = pd.concat([df2, df1], axis=1)
        if d == int(len(shuffled_times)*0.8):
            df_test = df2
        else:
            df_test = pd.concat([df_test,df2],axis=0)
# Out:
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# Empty DataFrame
# Columns: [time, ACTON275]
# Index: []
# ...
#           time  ACTON275
# 41233  1212.33  4.840049
#           time  ACTON275
# 41233  1212.33  4.840049
#           time  ACTON275
# 41233  1212.33  4.840049
#           time  ACTON275
# 41233  1212.33  4.840049
#           time  ACTON275
# 41238  1212.38  4.852259
#           time  ACTON275
# 41239  1212.39  4.830281
#          time  ACTON275
# 41240  1212.4  4.835165
#           time  ACTON275
# 41241  1212.41  4.857143
#           time  ACTON275
# 41242  1212.42  4.832723
#           time  ACTON275
# 41243  1212.43  4.869353
#           time  ACTON275
# 41244  1212.44  4.808303
#           time  ACTON275
# 41245  1212.45  4.854701
#           time  ACTON275
# 41246  1212.46  4.844933
#           time  ACTON275
# 41247  1212.47  4.847375
#           time  ACTON275
# 41248  1212.48  4.847375
#           time  ACTON275
# 41249  1212.49  4.835165
#          time  ACTON275
# 41250  1212.5  4.827839
#           time  ACTON275
# 41251  1212.51  4.827839
#           time  ACTON275
# 41252  1212.52  4.835165
#           time  ACTON275
# 41375  1213.75  4.898657
#           time  ACTON275
# 41376  1213.76  4.932845
#           time  ACTON275
# 41377  1213.77  4.913309
#           time  ACTON275
# 41378  1213.78  4.920635
#           time  ACTON275
# 41379  1213.79  4.915751
#          time  ACTON275
# 41380  1213.8  4.932845
#           time  ACTON275
# 41381  1213.81  4.935287
#           time  ACTON275
# 41382  1213.82  4.930403
#           time  ACTON275
# 41383  1213.83  4.905983
#           time  ACTON275
# 41383  1213.83  4.905983
#           time  ACTON275
# 41383  1213.83  4.905983
#           time  ACTON275
# 41383  1213.83  4.905983
#           time  ACTON275
# 41383  1213.83  4.905983
#           time  ACTON275
# 41388  1213.88  4.952381
#           time  ACTON275
# 41389  1213.89  4.901099
#          time  ACTON275
# 41390  1213.9  4.952381
#           time  ACTON275
# 41391  1213.91  4.901099
#           time  ACTON275
# 41392  1213.92  4.920635
#           time  ACTON275
# 41393  1213.93  4.932845
#           time  ACTON275
# 41394  1213.94  4.945055
#           time  ACTON275
# 41395  1213.95  4.942613
#           time  ACTON275
# 41396  1213.96  4.940171
#           time  ACTON275
# 41397  1213.97  4.954823
#           time  ACTON275
# 41398  1213.98  4.971917
#           time  ACTON275
# 41399  1213.99  4.959707
#          time  ACTON275
# 41400  1214.0  4.949939
#           time  ACTON275
# 41401  1214.01  4.942613
#           time  ACTON275
# 41402  1214.02  4.996337
#           time  ACTON275
# 41403  1214.03  5.013431
#           time  ACTON275
# 41404  1214.04  5.057387
#           time  ACTON275
# 41405  1214.05  5.015873
#           time  ACTON275
# 41406  1214.06  5.037851
#           time  ACTON275
# 41407  1214.07  5.032967
#           time  ACTON275
# 41408  1214.08  5.067155
#           time  ACTON275
# 41408  1214.08  5.067155
#           time  ACTON275
# 41408  1214.08  5.067155
#           time  ACTON275
# 41408  1214.08  5.067155
#           time  ACTON275
# 41408  1214.08  5.067155
#           time  ACTON275
# 41413  1214.13  5.084249
#           time  ACTON275
# 41414  1214.14  5.086691
#           time  ACTON275
# 41415  1214.15  5.106227
#           time  ACTON275
# 41416  1214.16  5.091575
#           time  ACTON275
# 41417  1214.17  5.089133
#           time  ACTON275
# 41418  1214.18  5.069597
#           time  ACTON275
# 41419  1214.19  5.096459
#          time  ACTON275
# 41420  1214.2  5.094017
#           time  ACTON275
# 41421  1214.21  5.120879
#           time  ACTON275
# 41422  1214.22  5.089133
#           time  ACTON275
# 41423  1214.23  5.047619
#           time  ACTON275
# 41424  1214.24  5.067155
#           time  ACTON275
# 41425  1214.25  5.094017
#           time  ACTON275
# 41426  1214.26  5.020757
#           time  ACTON275
# 41427  1214.27  5.081807
#           time  ACTON275
# 41428  1214.28  5.062271
#           time  ACTON275
# 41429  1214.29  5.069597
#          time  ACTON275
# 41430  1214.3  5.062271
#           time  ACTON275
# 41431  1214.31  5.030525
#           time  ACTON275
# 41432  1214.32  5.037851
#           time  ACTON275
# 41433  1214.33  5.023199
#           time  ACTON275
# 41433  1214.33  5.023199
#           time  ACTON275
# 41433  1214.33  5.023199
#           time  ACTON275
# 41433  1214.33  5.023199
#           time  ACTON275
# 41433  1214.33  5.023199
#           time  ACTON275
# 41438  1214.38  4.993895
#           time  ACTON275
# 41439  1214.39  5.015873
#          time  ACTON275
# 41440  1214.4  4.984127
#           time  ACTON275
# 41441  1214.41  4.964591
#           time  ACTON275
# 41442  1214.42  4.954823
#           time  ACTON275
# 41443  1214.43  4.937729
#           time  ACTON275
# 41444  1214.44  4.930403
#           time  ACTON275
# 41445  1214.45  4.957265
#           time  ACTON275
# 41446  1214.46  4.932845
#           time  ACTON275
# 41447  1214.47  4.949939
#           time  ACTON275
# 41448  1214.48  4.925519
#           time  ACTON275
# 41449  1214.49  4.752137
#          time  ACTON275
# 41450  1214.5  4.776557
#           time  ACTON275
# 41451  1214.51  4.891331
#           time  ACTON275
# 41452  1214.52  4.913309
#           time  ACTON275
# 41453  1214.53  4.881563
#           time  ACTON275
# 41454  1214.54  4.879121
#           time  ACTON275
# 41455  1214.55  4.871795
#           time  ACTON275
# 41456  1214.56  4.876679
#           time  ACTON275
# 41457  1214.57  4.864469
#           time  ACTON275
# 41458  1214.58  4.866911
#           time  ACTON275
# 41458  1214.58  4.866911
#           time  ACTON275
# 41458  1214.58  4.866911
#           time  ACTON275
# 41458  1214.58  4.866911
#           time  ACTON275
# 41458  1214.58  4.866911
#           time  ACTON275
# 41463  1214.63  4.854701
#           time  ACTON275
# 41464  1214.64  4.832723
#           time  ACTON275
# 41465  1214.65  4.796093
#           time  ACTON275
# 41466  1214.66  4.805861
#           time  ACTON275
# 41467  1214.67  4.796093
#           time  ACTON275
# 41468  1214.68  4.815629
#           time  ACTON275
# 41469  1214.69  4.822955
#          time  ACTON275
# 41470  1214.7  4.766789
#           time  ACTON275
# 41471  1214.71  4.808303
#           time  ACTON275
# 41472  1214.72  4.805861
#           time  ACTON275
# 41473  1214.73  4.778999
#           time  ACTON275
# 41474  1214.74  4.747253
#           time  ACTON275
# 41475  1214.75  4.793651
#           time  ACTON275
# 41476  1214.76  4.766789
#           time  ACTON275
# 41477  1214.77  4.757021
#           time  ACTON275
# 41478  1214.78  4.771673
#           time  ACTON275
# 41479  1214.79  4.778999
#          time  ACTON275
# 41480  1214.8  4.796093
#           time  ACTON275
# 41481  1214.81  4.796093
#           time  ACTON275
# 41482  1214.82  4.822955
#           time  ACTON275
# 41483  1214.83  4.793651
#           time  ACTON275
# 41483  1214.83  4.793651
#           time  ACTON275
# 41483  1214.83  4.793651
#           time  ACTON275
# 41483  1214.83  4.793651
#           time  ACTON275
# 41483  1214.83  4.793651
#           time  ACTON275
# 41488  1214.88  4.825397
#           time  ACTON275
# 41489  1214.89  4.835165
#          time  ACTON275
# 41490  1214.9  4.781441
#           time  ACTON275
# 41491  1214.91  4.825397
#           time  ACTON275
# 41492  1214.92  4.805861
#           time  ACTON275
# 41493  1214.93  4.837607
#           time  ACTON275
# 41494  1214.94  4.827839
#           time  ACTON275
# 41495  1214.95  4.859585
#           time  ACTON275
# 41496  1214.96  4.864469
#           time  ACTON275
# 41497  1214.97  4.830281
#           time  ACTON275
# 41498  1214.98  4.835165
#           time  ACTON275
# 41499  1214.99  4.866911
#          time  ACTON275
# 41500  1215.0  4.866911
#           time  ACTON275
# 41501  1215.01  4.920635
#           time  ACTON275
# 41502  1215.02  4.881563
#           time  ACTON275
# 41503  1215.03  4.874237
#           time  ACTON275
# 41504  1215.04  4.898657
#           time  ACTON275
# 41505  1215.05  4.910867
#           time  ACTON275
# 41506  1215.06  4.818071
#           time  ACTON275
# 41507  1215.07  4.910867
#           time  ACTON275
# 41508  1215.08  4.908425
#           time  ACTON275
# 41508  1215.08  4.908425
#           time  ACTON275
# 41508  1215.08  4.908425
#           time  ACTON275
# 41508  1215.08  4.908425
#           time  ACTON275
# 41508  1215.08  4.908425
#           time  ACTON275
# 41513  1215.13  4.871795
#           time  ACTON275
# 41514  1215.14  4.913309
#           time  ACTON275
# 41515  1215.15  4.923077
#           time  ACTON275
# 41516  1215.16  4.908425
#           time  ACTON275
# 41517  1215.17  4.923077
#           time  ACTON275
# 41518  1215.18  4.903541
#           time  ACTON275
# 41519  1215.19  4.930403
#          time  ACTON275
# 41520  1215.2  4.901099
#           time  ACTON275
# 41521  1215.21  4.893773
#           time  ACTON275
# 41522  1215.22  4.896215
#           time  ACTON275
# 41523  1215.23  4.905983
#           time  ACTON275
# 41524  1215.24  4.915751
#           time  ACTON275
# 41525  1215.25  4.888889
#           time  ACTON275
# 41526  1215.26  4.920635
#           time  ACTON275
# 41527  1215.27  4.930403
#           time  ACTON275
# 41528  1215.28  4.969475
#           time  ACTON275
# 41529  1215.29  4.952381
#          time  ACTON275
# 41530  1215.3  4.927961
#           time  ACTON275
# 41531  1215.31  4.925519
#           time  ACTON275
# 41532  1215.32  4.959707
#           time  ACTON275
# 41533  1215.33  5.006105
#           time  ACTON275
# 41533  1215.33  5.006105
#           time  ACTON275
# 41533  1215.33  5.006105
#           time  ACTON275
# 41533  1215.33  5.006105
#           time  ACTON275
# 41533  1215.33  5.006105
#           time  ACTON275
# 41538  1215.38  4.932845
#           time  ACTON275
# 41539  1215.39  4.949939
#          time  ACTON275
# 41540  1215.4  4.949939
#           time  ACTON275
# 41541  1215.41  4.840049
#           time  ACTON275
# 41542  1215.42  4.849817
#           time  ACTON275
# 41543  1215.43  4.915751
#           time  ACTON275
# 41544  1215.44  4.925519
#           time  ACTON275
# 41545  1215.45  4.898657
#           time  ACTON275
# 41546  1215.46  4.915751
#           time  ACTON275
# 41547  1215.47  4.910867
#           time  ACTON275
# 41548  1215.48  4.869353
#           time  ACTON275
# 41549  1215.49  4.866911
#          time  ACTON275
# 41550  1215.5  4.901099
#           time  ACTON275
# 41551  1215.51  4.937729
#           time  ACTON275
# 41552  1215.52  4.884005
#           time  ACTON275
# 41553  1215.53  4.888889
#           time  ACTON275
# 41554  1215.54  4.891331

# %%
print('Train dataset:', len(df_train))
print('Trest dataset:', len(df_test))

# %%
df_train.to_csv('data_train_'+str(w_length)+'.csv',index=False)
df_test.to_csv('data_test_'+str(w_length)+'.csv',index=False)
